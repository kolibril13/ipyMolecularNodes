# %%
# !pip install git+https://github.com/bradyajohnston/MolecularNodes.git@dev-headless

# %%
import MolecularNodes as mn
from IPython.display import Image

obj = mn.load.molecule_rcsb("2o39", starting_style=2, setup_nodes=True)
mn.render.render_object(obj, "tests.png")
Image(filename="tests.png")
# Out:
# Device with name Apple M1 supports metal minimum requirements
# Finsihed opening molecule after 0.19129399999999963 seconds
# Adding object to scene.
# Added res_id after 0.0002419999999996314 s
# Added res_name after 0.0030330000000002855 s
# Added atomic_number after 0.0025129999999999875 s
# Added b_factor after 3.799999999998249e-05 s
# Added vdw_radii after 0.0025449999999995754 s
# Added chain_id after 0.0004569999999999297 s
# Added entity_id after 0.00023799999999996047 s
# Added atom_name after 0.0015559999999998908 s
# Added lipophobicity after 0.002835000000000143 s
# Added charge after 0.0028260000000002172 s
# Added is_backbone after 0.00027199999999982793 s
# Added is_alpha_carbon after 8.900000000000574e-05 s
# Added is_solvent after 8.900000000000574e-05 s
# Added is_nucleic after 0.0004499999999998394 s
# Added is_peptide after 0.0006900000000000794 s
# Added is_hetero after 7.199999999984996e-05 s
# Added is_carb after 0.00044300000000019324 s
# Added sec_struct after 0.0011309999999999931 s
# Finsihed add object after 0.02488299999999999 seconds
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:42.34M (Peak 42.89M) | Time:00:00.08 | Syncing Light
# Fra:1 Mem:42.34M (Peak 42.89M) | Time:00:00.08 | Syncing Camera
# Fra:1 Mem:42.34M (Peak 42.89M) | Time:00:00.08 | Syncing 2o39
# Fra:1 Mem:45.48M (Peak 45.48M) | Time:00:00.10 | Rendering 1 / 64 samples
# Fra:1 Mem:43.16M (Peak 45.48M) | Time:00:00.43 | Rendering 26 / 64 samples
# Fra:1 Mem:43.16M (Peak 45.48M) | Time:00:00.73 | Rendering 51 / 64 samples
# Fra:1 Mem:43.16M (Peak 45.48M) | Time:00:00.89 | Rendering 64 / 64 samples
# Saved: 'tests.png'
#  Time: 00:01.08 (Saving: 00:00.16)
