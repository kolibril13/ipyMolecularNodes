# %%
import sys
import os

sys.stdout = open(os.devnull, 'w')
sys.stderr = open(os.devnull, 'w')

def clear_scene():
    bpy.ops.object.select_all(action="DESELECT")
    bpy.ops.object.select_by_type(type="MESH")
    bpy.ops.object.delete()

def render_image():
    # Render
    path = "test.png"
    bpy.context.scene.render.resolution_x = 1000
    bpy.context.scene.render.resolution_y = 500
    bpy.context.scene.render.image_settings.file_format = 'PNG'
    bpy.context.scene.render.image_settings.color_mode = 'RGBA'
    bpy.context.scene.render.film_transparent = True
    bpy.context.scene.render.image_settings.file_format = "PNG"
    bpy.context.scene.render.filepath = path
    bpy.ops.render.render(write_still=True)
    bpy.data.images["Render Result"].save_render(filepath=bpy.context.scene.render.filepath)

    display(Image(filename=path))

import bpy
from IPython.display import display, Image

clear_scene()

# Camera
camera = bpy.data.objects["Camera"]
camera.location = (5, -3, 4)
camera.data.dof.use_dof = True
camera.data.dof.focus_distance = 4
camera.data.dof.aperture_fstop = 4
# Out:
# Device with name Apple M1 supports metal minimum requirements
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:68.34M (Peak 69.22M) | Time:00:00.13 | Syncing Light
# Fra:1 Mem:68.34M (Peak 69.22M) | Time:00:00.13 | Syncing Camera
# Fra:1 Mem:68.35M (Peak 69.22M) | Time:00:00.13 | Syncing 4N7N
# Fra:1 Mem:81.95M (Peak 85.60M) | Time:00:00.16 | Rendering 1 / 64 samples
# Fra:1 Mem:71.11M (Peak 85.60M) | Time:00:00.33 | Rendering 26 / 64 samples
# Fra:1 Mem:71.11M (Peak 85.60M) | Time:00:00.45 | Rendering 51 / 64 samples
# Fra:1 Mem:71.11M (Peak 85.60M) | Time:00:00.51 | Rendering 64 / 64 samples
# Saved: 'test.png'
#  Time: 00:00.69 (Saving: 00:00.15)
#
# Fra:1 Mem:69.70M (Peak 72.51M) | Time:00:00.01 | Syncing Light
# Fra:1 Mem:69.70M (Peak 72.51M) | Time:00:00.01 | Syncing Camera
# Fra:1 Mem:69.70M (Peak 72.51M) | Time:00:00.01 | Syncing 4N7P
# Fra:1 Mem:83.30M (Peak 86.97M) | Time:00:00.02 | Rendering 1 / 64 samples
# ...

# %%
import jupyter_capture_output

# %%
# %%capture_img --path "im1.png"
# import molecularnodes as mn
#
#
# clear_scene()
# molecule = mn.load.molecule_rcsb("6L5V", starting_style="cartoon", center_molecule=True)
#
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Lightness"].default_value = 0.4
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Saturation"].default_value = 1
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Seed"].default_value = 1
#
# molecule.location = (0, 2, 0.7)
# molecule.rotation_euler = (-1.4, 2.7, 0)
# camera.data.dof.focus_distance = 10
# scale = 4.5
#
# molecule.scale = (scale,scale,scale)
#
# render_image()

# %%
# %%capture_img --path "im2.png"
#
# import molecularnodes as mn
#
#
# clear_scene()
# molecule = mn.load.molecule_rcsb("8PBF", starting_style="cartoon", center_molecule=True)
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Lightness"].default_value = 0.4
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Saturation"].default_value = 1
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Seed"].default_value = 5
#
# molecule.location = (0, 2, 0.7)
# molecule.rotation_euler = (-1.4, 2.7, 0)
# camera.data.dof.focus_distance = 10
# scale = 4.5
#
# molecule.scale = (scale,scale,scale)
#
# render_image()

# %%
# %%capture_img --path "im3.png"
#
# import molecularnodes as mn
#
#
# clear_scene()
# molecule = mn.load.molecule_rcsb("4c4c", starting_style="cartoon", center_molecule=True)
#
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Lightness"].default_value = 0.4
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Saturation"].default_value = 1
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Seed"].default_value = 6
#
#
# molecule.location = (0, 2, 0.7)
# molecule.rotation_euler = (-1.4, 2.7, 0)
# camera.data.dof.focus_distance = 10
# scale = 4.5
#
# molecule.scale = (scale,scale,scale)
#
# render_image()

# %%
# %%capture_img --path "im4.png"
#
# import molecularnodes as mn
#
#
# clear_scene()
# molecule = mn.load.molecule_rcsb("5xh3", starting_style="cartoon", center_molecule=True)
#
#
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Lightness"].default_value = 0.4
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Saturation"].default_value = 1
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Seed"].default_value = 8
#
# molecule.location = (0, 2, 0.7)
# molecule.rotation_euler = (-1.4, 2.7, 0)
# camera.data.dof.focus_distance = 10
# scale = 4.5
#
# molecule.scale = (scale,scale,scale)
#
# render_image()

# %%
# %%capture_img --path "im5.png"
#
# import molecularnodes as mn
#
#
# clear_scene()
# molecule = mn.load.molecule_rcsb("6L5V", starting_style="cartoon", center_molecule=True)
#
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Lightness"].default_value = 0.4
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Saturation"].default_value = 1
# molecule.modifiers["MolecularNodes"].node_group.nodes["MN_color_attribute_random"].inputs["Seed"].default_value = 11
#
# molecule.location = (0, 2, 0.7)
# molecule.rotation_euler = (-1.4, 2.7, 0)
# camera.data.dof.focus_distance = 10
# scale = 4.5
#
# molecule.scale = (scale,scale,scale)
#
# render_image()
